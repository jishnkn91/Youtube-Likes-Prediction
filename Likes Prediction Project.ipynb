# %% [markdown]
# # YouTube Likes Prediction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("C:\\Users\\user\\Downloads\\Project3\\USvideos.xlsx")

# %%
df
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 41041   6SvSYSE122      17.14.11
# 41042   6SvSYSE123      17.14.11
# 41043   6SvSYSE124      17.14.11
# 41044   6SvSYSE125      17.14.11
# 41045   6SvSYSE126      17.14.11
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 41041                         HomeMade Electric Airplane
# 41042           Founding An Inbreeding-Free Space Colony
# 41043                   How Can You Control Your Dreams?
# 41044  The Making of Hela's Headdress from Thor: Ragn...
# 41045  Is It Dangerous To Talk To A Camera While Driv...
#
#                channel_title  category_id              publish_time  \
# 0               CaseyNeistat           22  2017-11-13T17:13:01.000Z
# 1            LastWeekTonight           24  2017-11-13T07:30:00.000Z
# 2               Rudy Mancuso           23  2017-11-12T19:05:24.000Z
# 3      Good Mythical Morning           24  2017-11-13T11:00:04.000Z
# 4                   nigahiga           24  2017-11-12T18:01:41.000Z
# ...                      ...          ...                       ...
# 41041            PeterSripol           28  2017-11-13T15:30:17.000Z
# 41042                SciShow           27  2017-11-12T22:00:01.000Z
# 41043            Life Noggin           27  2017-11-13T14:00:03.000Z
# 41044                 Tested           28  2017-11-12T15:00:01.000Z
# 41045              Tom Scott           27  2017-11-13T16:00:03.000Z
#
#                                                     tags    views   likes  \
# 0                                        SHANtell martin   748374   57527
# 1      last week tonight trump presidency|"last week ...  2418783   97185
# 2      racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
# 3      rhett and link|"gmm"|"good mythical morning"|"...   343168   10172
# 4      ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731  132235
# ...                                                  ...      ...     ...
# 41041  ultralight|"airplane"|"homemade"|"DIY"|"hoverb...  1064798   60008
# 41042  SciShow|"science"|"Hank"|"Green"|"education"|"...        #       #
# 41043  life noggin|"life noggin youtube"|"youtube lif...  1064798   60008
# 41044  tested|"testedcom"|"designercon 2017"|"preview...      NaN     NaN
# 41045  tom scott|"tomscott"|"built for science"|"nati...  1064798   60008
#
#       dislikes comment_count                                  thumbnail_link  \
# 0         2966         15954  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1         6146         12703  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# 2         5339          8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3          666          2146  https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg
# 4         1989         17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# ...        ...           ...                                             ...
# 41041      382            20  https://i.ytimg.com/vi/eNSN6qet1kE/default.jpg
# 41042        #             *  https://i.ytimg.com/vi/B5HORANmzHw/default.jpg
# 41043      382            20  https://i.ytimg.com/vi/vU14JY3x81A/default.jpg
# 41044      NaN           NaN  https://i.ytimg.com/vi/6VhU_T463sU/default.jpg
# 41045      382            20  https://i.ytimg.com/vi/_-aDHxoblr4/default.jpg
#
#        comments_disabled  ratings_disabled  video_error_or_removed  \
# 0                  False             False                   False
# 1                  False             False                   False
# 2                  False             False                   False
# 3                  False             False                   False
# 4                  False             False                   False
# ...                  ...               ...                     ...
# 41041              False             False                   False
# 41042              False             False                   False
# 41043              False             False                   False
# 41044              False             False                   False
# 41045              False             False                   False
#
#                                              description
# 0      SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      One year after the presidential election, John...
# 2      WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      Today we find out if Link is a Nickelback amat...
# 4      I know it's been a while since we did this sho...
# ...                                                  ...
# 41041  aaaannnd now to fly out of ground effect! The ...
# 41042  Thanks to 23AndMe for supporting SciShow. Thes...
# 41043  What if there was a way to control your dreams...
# 41044  At this year's DesignerCon, we meet up with Ir...
# 41045  I'm visiting the University of Iowa's National...
#
# [41046 rows x 16 columns]

# %%
df.shape
# Out:
# (41046, 16)

# %%
df.isna().any().any()
# Out:
# True

# %%
df.isna().sum()
# Out:
# video_id                  416
# trending_date               0
# title                       0
# channel_title               0
# category_id                 0
# publish_time                0
# tags                        0
# views                      30
# likes                      34
# dislikes                   37
# comment_count              37
# thumbnail_link              0
# comments_disabled           0
# ratings_disabled            0
# video_error_or_removed      0
# description               570
# dtype: int64

# %%
df[df["views"].apply(lambda x: pd.isna(x))].head()
# Out:
#           video_id trending_date  \
# 40950     PwfrtAFY      17.14.11
# 40954    gHQz0KiKM      17.14.11
# 40957     jrXwC9vc      17.14.11
# 40959  9wRQljFNDW8      17.14.11
# 40962     Gn66oK_A      17.14.11
#
#                                                    title     channel_title  \
# 40950  The Trump Presidency: Last Week Tonight with J...   LastWeekTonight
# 40954                              2 Weeks with iPhone X          iJustine
# 40957  The Greatest Showman | Official Trailer 2 [HD]...  20th Century Fox
# 40959  Dion Lewis' 103-Yd Kick Return TD vs. Denver! ...               NFL
# 40962             Which Countries Are About To Collapse?     NowThis World
#
#        category_id              publish_time  \
# 40950           24  2017-11-13T07:30:00.000Z
# 40954           28  2017-11-13T19:07:23.000Z
# 40957            1  2017-11-13T14:00:23.000Z
# 40959           17  2017-11-13T02:05:26.000Z
# 40962           25  2017-11-12T14:00:00.000Z
#
#                                                     tags views  likes  \
# 40950  last week tonight trump presidency|"last week ...   NaN    NaN
# 40954  ijustine|"week with iPhone X"|"iphone x"|"appl...   NaN    NaN
# 40957  Trailer|"Hugh Jackman"|"Michelle Williams"|"Za...   NaN  60008
# 40959  NFL|"Football"|"offense"|"defense"|"afc"|"nfc"...   NaN  60008
# 40962  nowthis|"nowthis world"|"world news"|"nowthis ...   NaN    NaN
#
#       dislikes comment_count                                  thumbnail_link  \
# 40950      NaN           NaN  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# 40954      NaN           NaN  https://i.ytimg.com/vi/gHZ1Qz0KiKM/default.jpg
# 40957      382            20  https://i.ytimg.com/vi/jr9QtXwC9vc/default.jpg
# 40959      382            20  https://i.ytimg.com/vi/9wRQljFNDW8/default.jpg
# 40962      NaN           NaN  https://i.ytimg.com/vi/GgVmn66oK_A/default.jpg
#
#        comments_disabled  ratings_disabled  video_error_or_removed  \
# 40950              False             False                   False
# 40954              False             False                   False
# 40957              False             False                   False
# 40959              False             False                   False
# 40962              False             False                   False
#
#                                              description
# 40950  One year after the presidential election, John...
# 40954  Using the iPhone for the past two weeks -- her...
# 40957  Inspired by the imagination of P.T. Barnum, Th...
# 40959  New England Patriots returner Dion Lewis blast...
# 40962  The world at large is improving, but some coun...

# %% [markdown]
# # Data Cleaning

# %%
df["video_id"] = df["video_id"].fillna(value="")

# %%
df["video_id"].isna().any().any()
# Out:
# False

# %%
df["description"] = df["description"].fillna(value="")

# %%
df["description"].isna().any().any()
# Out:
# False

# %%
df["views"]=df.views.fillna(method="bfill")

# %%
df["views"].isna().any().any()
# Out:
# False

# %%
df["likes"]=df.likes.fillna(method="bfill")

# %%
df["likes"].isna().any().any()
# Out:
# False

# %%
df["dislikes"]=df.dislikes.fillna(method="bfill")

# %%
df["dislikes"].isna().any().any()
# Out:
# False

# %%
df["comment_count"]=df.comment_count.fillna(method="bfill")

# %%
df["comment_count"].isna().any().any()
# Out:
# False

# %%
df
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 41041   6SvSYSE122      17.14.11
# 41042   6SvSYSE123      17.14.11
# 41043   6SvSYSE124      17.14.11
# 41044   6SvSYSE125      17.14.11
# 41045   6SvSYSE126      17.14.11
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 41041                         HomeMade Electric Airplane
# 41042           Founding An Inbreeding-Free Space Colony
# 41043                   How Can You Control Your Dreams?
# 41044  The Making of Hela's Headdress from Thor: Ragn...
# 41045  Is It Dangerous To Talk To A Camera While Driv...
#
#                channel_title  category_id              publish_time  \
# 0               CaseyNeistat           22  2017-11-13T17:13:01.000Z
# 1            LastWeekTonight           24  2017-11-13T07:30:00.000Z
# 2               Rudy Mancuso           23  2017-11-12T19:05:24.000Z
# 3      Good Mythical Morning           24  2017-11-13T11:00:04.000Z
# 4                   nigahiga           24  2017-11-12T18:01:41.000Z
# ...                      ...          ...                       ...
# 41041            PeterSripol           28  2017-11-13T15:30:17.000Z
# 41042                SciShow           27  2017-11-12T22:00:01.000Z
# 41043            Life Noggin           27  2017-11-13T14:00:03.000Z
# 41044                 Tested           28  2017-11-12T15:00:01.000Z
# 41045              Tom Scott           27  2017-11-13T16:00:03.000Z
#
#                                                     tags    views   likes  \
# 0                                        SHANtell martin   748374   57527
# 1      last week tonight trump presidency|"last week ...  2418783   97185
# 2      racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
# 3      rhett and link|"gmm"|"good mythical morning"|"...   343168   10172
# 4      ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731  132235
# ...                                                  ...      ...     ...
# 41041  ultralight|"airplane"|"homemade"|"DIY"|"hoverb...  1064798   60008
# 41042  SciShow|"science"|"Hank"|"Green"|"education"|"...        #       #
# 41043  life noggin|"life noggin youtube"|"youtube lif...  1064798   60008
# 41044  tested|"testedcom"|"designercon 2017"|"preview...  1064798   60008
# 41045  tom scott|"tomscott"|"built for science"|"nati...  1064798   60008
#
#       dislikes comment_count                                  thumbnail_link  \
# 0         2966         15954  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1         6146         12703  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# 2         5339          8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3          666          2146  https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg
# 4         1989         17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# ...        ...           ...                                             ...
# 41041      382            20  https://i.ytimg.com/vi/eNSN6qet1kE/default.jpg
# 41042        #             *  https://i.ytimg.com/vi/B5HORANmzHw/default.jpg
# 41043      382            20  https://i.ytimg.com/vi/vU14JY3x81A/default.jpg
# 41044      382            20  https://i.ytimg.com/vi/6VhU_T463sU/default.jpg
# 41045      382            20  https://i.ytimg.com/vi/_-aDHxoblr4/default.jpg
#
#        comments_disabled  ratings_disabled  video_error_or_removed  \
# 0                  False             False                   False
# 1                  False             False                   False
# 2                  False             False                   False
# 3                  False             False                   False
# 4                  False             False                   False
# ...                  ...               ...                     ...
# 41041              False             False                   False
# 41042              False             False                   False
# 41043              False             False                   False
# 41044              False             False                   False
# 41045              False             False                   False
#
#                                              description
# 0      SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      One year after the presidential election, John...
# 2      WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      Today we find out if Link is a Nickelback amat...
# 4      I know it's been a while since we did this sho...
# ...                                                  ...
# 41041  aaaannnd now to fly out of ground effect! The ...
# 41042  Thanks to 23AndMe for supporting SciShow. Thes...
# 41043  What if there was a way to control your dreams...
# 41044  At this year's DesignerCon, we meet up with Ir...
# 41045  I'm visiting the University of Iowa's National...
#
# [41046 rows x 16 columns]

# %%
df.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                     object
# likes                     object
# dislikes                  object
# comment_count             object
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %%
df.views.unique()
# Out:
# array([748374, 2418783, 3191434, ..., 5660813, 10306119, '#'],
#       dtype=object)

# %%
df.loc[df["views"]=="#"]
# Out:
#          video_id trending_date                                     title  \
# 41042  6SvSYSE123      17.14.11  Founding An Inbreeding-Free Space Colony
#
#       channel_title  category_id              publish_time  \
# 41042       SciShow           27  2017-11-12T22:00:01.000Z
#
#                                                     tags views likes dislikes  \
# 41042  SciShow|"science"|"Hank"|"Green"|"education"|"...     #     #        #
#
#       comment_count                                  thumbnail_link  \
# 41042             *  https://i.ytimg.com/vi/B5HORANmzHw/default.jpg
#
#        comments_disabled  ratings_disabled  video_error_or_removed  \
# 41042              False             False                   False
#
#                                              description
# 41042  Thanks to 23AndMe for supporting SciShow. Thes...

# %%
df.views.replace("#",np.nan,inplace=True)
df["views"]=df.views.fillna(method="bfill")

# %%
df["views"]=df["views"].astype(float)

# %%
df["views"].dtypes
# Out:
# dtype('float64')

# %%
df.likes.unique()
# Out:
# array([57527, 97185, 146033, ..., 192957, 357079, '#'], dtype=object)

# %%
df.loc[df["likes"]=="#"]
# Out:
#          video_id trending_date                                     title  \
# 41042  6SvSYSE123      17.14.11  Founding An Inbreeding-Free Space Colony
#
#       channel_title  category_id              publish_time  \
# 41042       SciShow           27  2017-11-12T22:00:01.000Z
#
#                                                     tags      views likes  \
# 41042  SciShow|"science"|"Hank"|"Green"|"education"|"...  1064798.0     #
#
#       dislikes comment_count                                  thumbnail_link  \
# 41042        #             *  https://i.ytimg.com/vi/B5HORANmzHw/default.jpg
#
#        comments_disabled  ratings_disabled  video_error_or_removed  \
# 41042              False             False                   False
#
#                                              description
# 41042  Thanks to 23AndMe for supporting SciShow. Thes...

# %%
df.likes.replace("#",np.nan,inplace=True)
df["likes"]=df.likes.fillna(method="bfill")

# %%
df["likes"]=df["likes"].astype(float)
df["likes"].dtypes
# Out:
# dtype('float64')

# %%
df.dislikes.unique()
# Out:
# array([2966, 6146, 5339, ..., 4166, 212976, '#'], dtype=object)

# %%
df.dislikes.replace("#",np.nan,inplace=True)
df["dislikes"]=df.dislikes.fillna(method="bfill")

# %%
df["dislikes"]=df["dislikes"].astype(float)
df["dislikes"].dtypes
# Out:
# dtype('float64')

# %%
df.comment_count.unique()
# Out:
# array([15954, 12703, 8181, ..., 62610, 144795, '*'], dtype=object)

# %%
df.comment_count.replace("*",np.nan,inplace=True)
df["comment_count"]=df.comment_count.fillna(method="bfill")

# %%
df["comment_count"]=df["comment_count"].astype(float)
df["comment_count"].dtypes
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# video_id                   object
# trending_date              object
# title                      object
# channel_title              object
# category_id                 int64
# publish_time               object
# tags                       object
# views                     float64
# likes                     float64
# dislikes                  float64
# comment_count             float64
# thumbnail_link             object
# comments_disabled            bool
# ratings_disabled             bool
# video_error_or_removed       bool
# description                object
# dtype: object

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
#                                                 tags      views     likes  \
# 0                                    SHANtell martin   748374.0   57527.0
# 1  last week tonight trump presidency|"last week ...  2418783.0   97185.0
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434.0  146033.0
# 3  rhett and link|"gmm"|"good mythical morning"|"...   343168.0   10172.0
# 4  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731.0  132235.0
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0    2966.0        15954.0  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1    6146.0        12703.0  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# 2    5339.0         8181.0  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3     666.0         2146.0  https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg
# 4    1989.0        17518.0  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1  One year after the presidential election, John...
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3  Today we find out if Link is a Nickelback amat...
# 4  I know it's been a while since we did this sho...

# %%
df.shape
# Out:
# (41046, 16)

# %%
df.duplicated().sum()
# Out:
# 48

# %%
df[df.duplicated()]
# Out:
#           video_id trending_date  \
# 34899  QBL8IRJ5yHU      18.15.05
# 34900  t4pRQ0jn23Q      18.15.05
# 34901  j4KvrAUjn6c      18.15.05
# 34902  MAjY8mCTXWk      18.15.05
# 34903  xhs8tf1v__w      18.15.05
# 34904  E21NATEP9QI      18.15.05
# 34924  mma|"ufc"|"amanda nunes"|"main event"|"raquel ...    769802.0
# 34925  Kelly Clarkson|"Meaning of Life"|"mol"|"Offici...    494211.0
# 34926  vat19|"vat19 nanodots"|"vat19 infinity gauntle...   2227658.0
# 34927  ryan|"higa"|"higatv"|"nigahiga"|"fortnite"|"th...   8289563.0
# 34928  timed mile in pe|"hannah"|"stocking"|"anwar"|"...   2271926.0
# 34929  kids games|"family games"|"challenges"|"compet...   2058569.0
# 34930  britain's got talent|"britains got talent"|"br...   1670008.0
# 34931  this is america|"childish gambino"|"donald glo...   3513129.0
# 34932  Buzzfeed|"eating your feed"|"viral food"|"cinn...   1207080.0
# 34933                                             [none]   2652713.0
# 34934  jaclynhill1|"jaclyn hill"|"makeup tutorial"|"s...   2288505.0
# 34935  Jacksfilms|"Jack Douglass"|"YGS"|"YGS 100"|"YG...   1663506.0
# 34936  wearing fashion nova outfits for a week|"fashi...   4106029.0
# 34937  Rita Ora|"Rita"|"Ora"|"Your Song"|"Anywhere"|"...   4429079.0
# 34938  abc|"network"|"tv"|"television"|"late"|"night"...   4867281.0
# 34939  Dynamic robots|"Boston Dynamics"|"humanoid rob...   5650991.0
# 34940  michelle khare|"buzzfeed michelle"|"organize"|...   1122213.0
# 34941  Trailer|"Deadpool"|"20th Century Fox (Producti...  15960127.0
# 34942  comedy|"entertainment"|"will smith"|"will"|"sm...   2055638.0
# 34943  Clash Royale|"Clash Royale Game"|"Supercell"|"...  13418844.0
# 34944  charlie puth|"boy"|"charlie"|"puth"|"atlantic"...   2124177.0
# 34945  Jack and Dean|"OMFGItsJackAndDean"|"Jack Howar...    165617.0
# 34946  Christina Aguilera|"Pop"|"RCA Records Label"|"...   1869585.0
# 34947  espn|"espn live"|"dwane casey"|"raptors"|"toro...    472999.0
# 34948  John|"Mayer"|"New"|"Light"|"Snack"|"Money"|"Po...   1201548.0
#
#           likes  dislikes  comment_count  \
# 34899  188652.0    3124.0        33032.0
# 34900   49709.0    2380.0         7261.0
# 34901   77378.0   12160.0        15874.0
# 34902   40485.0    1042.0         4746.0
# 34903   16988.0     132.0         1308.0
# 34904   12356.0     307.0         1129.0
# 34905   60379.0    6857.0         7796.0
# 34906   19880.0     248.0          669.0
# 34907   11734.0    1468.0         1870.0
# 34908  103430.0    8028.0        13293.0
# 34909   17920.0      79.0          642.0
# 34910   50065.0    2345.0         6732.0
# 34911   25829.0    2643.0         3698.0
# 34913   20251.0    3290.0         3567.0
# 34914   10561.0     337.0         1384.0
# 34915   20323.0    1108.0         3323.0
# 34916   19909.0     744.0         5017.0
# 34917    1488.0     251.0         1087.0
# 34918   15750.0    1919.0         1261.0
# 34919   51318.0    1359.0         4332.0
# 34921    5290.0    1861.0          546.0
# 34922    9815.0     330.0         1489.0
# 34923    6773.0     364.0          947.0
# 34924    2777.0     667.0         1285.0
# 34925   28080.0     426.0         1644.0
# 34926   29191.0    1157.0         4092.0
# 34927  408385.0   10966.0        21837.0
# 34928   78125.0    4191.0         5868.0
# 34929   32574.0    4195.0         5227.0
# 34930   25506.0     740.0            0.0
# 34931  106481.0    6922.0        18647.0
# 34933  https://i.ytimg.com/vi/rQEqKZ7CJlk/default.jpg              False
# 34934  https://i.ytimg.com/vi/OXVm3fhYsEo/default.jpg              False
# 34935  https://i.ytimg.com/vi/ksjWPxFPsos/default.jpg              False
# 34936  https://i.ytimg.com/vi/UQkBcHLZOqU/default.jpg              False
# 34937  https://i.ytimg.com/vi/mdWcaWBxxcY/default.jpg              False
# 34938  https://i.ytimg.com/vi/Am6NHDbj6XA/default.jpg              False
# 34939  https://i.ytimg.com/vi/vjSohj-Iclc/default.jpg              False
# 34940  https://i.ytimg.com/vi/CPjWgk0UXps/default.jpg              False
# 34941  https://i.ytimg.com/vi/uxbQATBAXf8/default.jpg              False
# 34942  https://i.ytimg.com/vi/y_WoOYybCro/default.jpg              False
# 34943  https://i.ytimg.com/vi/oSEeK9yDNQI/default.jpg              False
# 34944  https://i.ytimg.com/vi/iILJvqrAQ_w/default.jpg              False
# 34945  https://i.ytimg.com/vi/zcEE8J2Bqa8/default.jpg              False
# 34946  https://i.ytimg.com/vi/q1jzwV_s8_Y/default.jpg              False
# 34947  https://i.ytimg.com/vi/mkz1zoo15zI/default.jpg              False
# 34948  https://i.ytimg.com/vi/2PH7dK6SLC8/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 34899             False                   False
# 34900             False                   False
# 34901             False                   False
# 34902             False                   False
# 34903             False                   False
# 34904             False                   False
# 34905             False                   False
# 34906             False                   False
# 34907             False                   False
# 34908             False                   False
# 34909             False                   False
# 34910             False                   False
# 34911             False                   False
# 34913             False                   False
# 34914             False                   False
# 34915             False                   False
# 34916             False                   False
# 34917             False                   False
# 34918             False                   False
# 34919             False                   False
# 34921             False                   False
# 34922             False                   False
# 34923             False                   False
# 34924             False                   False
# 34925             False                   False
# 34926             False                   False
# 34927             False                   False
# 34928             False                   False
# 34929             False                   False
# 34930             False                   False
# 34931             False                   False
# 34932             False                   False
# 34933             False                   False
# 34934             False                   False
# 34935             False                   False
# 34936             False                   False
# 34937             False                   False
# 34938             False                   False
# 34939             False                   False
# 34940             False                   False
# 34941             False                   False
# 34942             False                   False
# 34943             False                   False
# 34944             False                   False
# 34945             False                   False
# 34946             False                   False
# 34947             False                   False
# 34948             False                   False
#
#                                              description
# 34899  I will never be able to say Thank You enough.....
# 34900  YoungBoy Never Broke Again goes Sneaker Shoppi...
# 34901  BEST MOM EVER! WANT TO SEE US IN NYC & NJ?!BUY...
# 34902  詞：周杰倫、宋健彰（彈頭）  曲：周杰倫憂鬱型男的走心旋律  用英式搖滾宣洩情傷不愛我就拉倒...
# 34903  Terry Crews takes the WIRED Autocomplete Inter...
# 34904  Many musicians prefer these 300-year-old instr...
# 34905  “Who is Lennox and why is he so special?”Credi...
# 34906  Sarah Paulson agreed to play a friendly game o...
# 34907  Gabby Barrett sings I Have Nothing by Whitney ...
# 34908  Fortnite, PUBG, Far Cry 5? Which game would yo...
# 34909  Millie is invited to help out at a Sugar Pine ...
# 34910  With a busy schedule, Jocko Willink finds time...
# 34911  SUBSCRIBE HERE ➡️ https://goo.gl/CitGia2ND CHA...
# 34913  In Todays 24 hour Box Fort video papa Jake bui...
# 34914  I'm always on the lookout for new amazing buff...
# 34915  iPhone 11 Leaks Are Ramping Up, Latest Feature...
# 34916  Watch all Do They Know It Eps! https://goo.gl/...
# 34917  Three new fissures have opened on Hawaii's Big...
# 34918  Three mother-child pairs (Cecily Strong, Aidy ...
# 34919  $15 Survival Kit Unboxing - https://youtu.be/0...
# 34921  In 2013, Flight 828 disappeared into thin air....
# 34922  In today's video we're making a cool glowing b...
# 34923  Download the best VPN on the market, NORDVPN n...
# 34924  The UFC on FOX crew breaks down Nunes' dominan...
# 34925  MEANING OF LIFE available now: https://Atlanti...
# 34926  NanoDots master builder, Edo, turned a huge pi...
# 34927  Play Fortnite for FREE here: https://pixly.go2...
# 34928  WATCH MORE ▶ https://youtu.be/twi_5o62cbUSUBSC...
# 34929  Team Edge Merchandise! ➡ https://teamedge.stor...
# 34930  Former Artful Dodger collaborator Lifford Shil...
# 34931  This is America by Childish Gambino reacted to...
# 34932  “OH MY GOD THEY”RE GIGANTIC!”Check us out on F...
# 34933  SpaceX is targeting launch of Bangabandhu Sate...
# 34934  *After looking over this footage, I definitely...
# 34935  Get your first 3 meals free by going here! ► h...
# 34936  I've been seeing this mysterious hashtag #Nova...
# 34937  Rita Ora 'Girls' ft. Cardi B, Bebe Rexha & Cha...
# 34938  Donald talks about his huge new video for This...
# 34939
# 34940  I worked with professional organizer Ashley Mo...
# 34941  Get your Deadpool 2 tickets at http://www.Dead...
# 34942  The full story of how an ex-girlfriend, Arseni...
# 34943  Rascals! What have they done now...New Card Ou...
# 34944  Voicenotes Available Now: https://Atlantic.lnk...
# 34945  That? That's a goblin living under the stairs....
# 34946  Pre-order Christina Aguilera’s new album ‘Libe...
# 34947  Richard Jefferson and Tracy McGrady share thei...
# 34948  Spotify: http://radi.al/NewLightSpotifyApple: ...

# %%
display(df.drop_duplicates(inplace=True))
# Out:
# None

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (40998, 16)

# %%
df.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40998.000000  4.099800e+04  4.099800e+04  4.099800e+04   4.099800e+04
# mean      19.978292  2.357612e+06  7.423799e+04  3.703844e+03   8.428625e+03
# std        7.568372  7.389230e+06  2.287299e+05  2.901231e+04   3.740930e+04
# min        1.000000  5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       17.000000  2.427982e+05  5.433250e+03  2.030000e+02   6.080000e+02
# 50%       24.000000  6.840395e+05  1.818050e+04  6.280000e+02   1.846000e+03
# 75%       25.000000  1.816615e+06  5.585475e+04  1.928000e+03   5.732500e+03
# max       43.000000  2.252119e+08  5.613827e+06  1.674420e+06   1.361580e+06

# %%
df.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
df1 = df.drop(['video_id', 'trending_date', 'title', 'channel_title',
       'publish_time', 'tags', 'thumbnail_link', 'comments_disabled', 'ratings_disabled',
       'video_error_or_removed', 'description'], axis=1)

df1.head()
# Out:
#    category_id      views     likes  dislikes  comment_count
# 0           22   748374.0   57527.0    2966.0        15954.0
# 1           24  2418783.0   97185.0    6146.0        12703.0
# 2           23  3191434.0  146033.0    5339.0         8181.0
# 3           24   343168.0   10172.0     666.0         2146.0
# 4           24  2095731.0  132235.0    1989.0        17518.0

# %%
df1.corr()
# Out:
#                category_id     views     likes  dislikes  comment_count
# category_id       1.000000 -0.168238 -0.173825 -0.033664      -0.076509
# views            -0.168238  1.000000  0.849170  0.472239       0.617691
# likes            -0.173825  0.849170  1.000000  0.447196       0.803069
# dislikes         -0.033664  0.472239  0.447196  1.000000       0.700200
# comment_count    -0.076509  0.617691  0.803069  0.700200       1.000000

# %%
corr = df1.corr()
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
df1.drop(["category_id"],axis=1,inplace=True)

# %%
df1.corr()
# Out:
#                   views     likes  dislikes  comment_count
# views          1.000000  0.849170  0.472239       0.617691
# likes          0.849170  1.000000  0.447196       0.803069
# dislikes       0.472239  0.447196  1.000000       0.700200
# comment_count  0.617691  0.803069  0.700200       1.000000

# %%
corr = df1.corr()
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
df1.shape
# Out:
# (40998, 4)

# %% [markdown]
# # Splitting data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
x = df1[['views', 'dislikes', 'comment_count']]
y = df1['likes']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=5)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (32798, 3)
# (32798,)
# (8200, 3)
# (8200,)

# %% [markdown]
# # 1.Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import metrics

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)      
lr_pred = lr.predict(x_test)  
print('RMSE:', np.sqrt(mean_squared_error(y_test, lr_pred, squared=False)))
print('r2 score: %.2f' % r2_score(y_test, lr_pred))
print("Test Accuracy : %.2f" % lr.score(x_test, y_test))
print("Train Accuracy : %.2f" % lr.score(x_train, y_train))
# Out:
# RMSE: 274.18414616937173
# r2 score: 0.89
# Test Accuracy : 0.89
# Train Accuracy : 0.88

# %%
labels = {'True Labels': y_test, 'Predicted Labels': lr_pred}
df_lr = pd.DataFrame(data = labels)
sns.lmplot(x='True Labels', y= 'Predicted Labels', data = df_lr)

# %% [markdown]
# # 2.Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import GridSearchCV
from sklearn import metrics

# %%
rf = RandomForestRegressor()
rf.fit(x_train, y_train)       
rf_pred = rf.predict(x_test)   
print('RMSE:', np.sqrt(mean_squared_error(y_test, rf_pred, squared=False)))
print('r2 score: %.2f' % r2_score(y_test, rf_pred))
print("Test Accuracy : %.2f" %  rf.score(x_test, y_test))
print("Train Accuracy : %.2f" % rf.score(x_train, y_train))
# Out:
# RMSE: 215.24788442914604
# r2 score: 0.96
# Test Accuracy : 0.96
# Train Accuracy : 0.99

# %%
labels_rf = {'True Labels': y_test, 'Predicted Labels': rf_pred}
df_rf = pd.DataFrame(data = labels_rf)
sns.lmplot(x='True Labels', y= 'Predicted Labels', data = df_rf)

# %% [markdown]
# # 3.XGBoost Regressor

# %%
from xgboost import XGBRegressor

# %%
#Simple XGBoost

# %%
xgb = XGBRegressor()
xgb.fit(x_train, y_train)       # Fitting model with x_train and y_train
xgb_pred = xgb.predict(x_test)  # Predicting the results
print('RMSE:', np.sqrt(mean_squared_error(y_test, xgb_pred, squared=False)))
print('r2 score: %.2f' % r2_score(y_test, xgb_pred))
print("Accuracy :",xgb.score(x_test, y_test))
print("Test Accuracy : %.2f" %  xgb.score(x_test, y_test))
print("Train Accuracy : %.2f" % xgb.score(x_train, y_train))
# Out:
# RMSE: 217.30862204791316
# r2 score: 0.96
# Accuracy : 0.9576865941416308
# Test Accuracy : 0.96
# Train Accuracy : 0.99

# %%
labels_xgb = {'True Labels': y_test, 'Predicted Labels': xgb_pred}
df_xgb = pd.DataFrame(data = labels_xgb)
sns.lmplot(x='True Labels', y= 'Predicted Labels', data = df_xgb)
